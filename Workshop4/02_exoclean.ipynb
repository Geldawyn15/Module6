# %% [markdown]
# # Nettoyer un texte : des exercices pour découvrir l’approche
#
# bag-of-words
#
# Lino Galiana
# 2024-04-12
#
# Cette page approfondit certains aspects présentés dans la
# [partie introductive](../../content/NLP/intro.html). Après avoir travaillé sur le
# *Comte de Monte Cristo*, on va continuer notre exploration de la littérature
# avec cette fois des auteurs anglophones :
#
# -   Edgar Allan Poe, (EAP) ;
# -   HP Lovecraft (HPL) ;
# -   Mary Wollstonecraft Shelley (MWS).
#
# Les données sont disponibles sur un CSV mis à disposition sur [`Github`](https://github.com/GU4243-ADS/spring2018-project1-ginnyqg/blob/master/data/spooky.csv). L’URL pour les récupérer directement est
# <https://github.com/GU4243-ADS/spring2018-project1-ginnyqg/raw/master/data/spooky.csv>.
#
# Le but va être dans un premier temps de regarder dans le détail les termes les plus fréquemment utilisés par les auteurs et de les représenter graphiquement. Il s’agit donc d’une approche basée sur l’analyse de fréquences.
# On prendra appui sur l’approche *bag of words* présentée dans le chapitre précédent<a name="cite_ref-1"></a>[<sup>\[1\]</sup>](#cite_note-1).
# Il n’y aura pas de modélisation particulière, ceci est réservé aux chapitres suivants.

# %% [raw]
# <a name="cite_note-1"></a>1. [^](#cite_ref-1)

# %% [markdown]
# L’approche *bag of words* est déjà, si on la pousse à ses limites, très intéressante. Elle peut notamment
# faciliter la mise en cohérence de différents corpus
# par la méthode des appariements flous
# (cf. [Galiana and Castillo (2022)](https://epic-davinci-acb57b.netlify.app/#1).
# Le [chapitre sur ElasticSearch](#elastic) présent dans cette partie du cours présente quelques
# éléments de ce travail sur les données de l’`OpenFoodFacts`.
#
# Ce chapitre s’inspire de plusieurs ressources disponibles en ligne:
#
# -   Un [premier *notebook* sur `Kaggle`](https://www.kaggle.com/enerrio/scary-nlp-with-spacy-and-keras)
#     et un [deuxième](https://www.kaggle.com/meiyizi/spooky-nlp-and-topic-modelling-tutorial/notebook) ;
# -   Un [dépôt `Github`](https://github.com/GU4243-ADS/spring2018-project1-ginnyqg) ;
#
# Les chapitres suivants permettront d’introduire aux enjeux de modélisation
# de corpus textuels. Dans un premier temps, le modèle `LDA` permettra d’explorer
# le principe des modèles bayésiens à couche cachées pour modéliser les sujets (*topics*)
# présents dans un corpus et segmenter ces *topics* selon les mots qui les composent.
#
# Le dernier chapitre de la partie visera à
# prédire quel texte correspond à quel auteur à partir d’un modèle `Word2Vec`.
# Cela sera un pas supplémentaire dans la formalisation puisqu’il s’agira de
# représenter chaque mot d’un texte sous forme d’un vecteur de grande dimension, ce
# qui nous permettra de rapprocher les mots entre eux dans un espace complexe.
# Cette technique, dite des plongements de mots (*Word Embeddings*),
# permet ainsi de transformer une information complexe difficilement quantifiable
# comme un mot
# en un objet numérique qui peut ainsi être rapproché d’autres par des méthodes
# algébriques. Pour découvrir ce concept, ce [post de blog](https://ssphub.netlify.app/post/word-embedding/)
# est particulièrement utile. En pratique, la technique des
# plongements de mots permet d’obtenir des tableaux comme celui-ci :
#
# <figure id="fig-relevanc-table-embedding">
# <img src="https://minio.lab.sspcloud.fr/lgaliana/generative-art/pythonds/word_embedding.png" />
# <figcaption>Figure 1: Illustration de l’intérêt des <em>embeddings</em> <span class="citation" data-cites="galianafuzzy">(Galiana and Castillo 2022)</span></figcaption>
# </figure>
#
# ## Librairies nécessaires
#
# Cette page évoquera les principales librairies pour faire du NLP, notamment :
#
# -   [NLTK](https://www.nltk.org/)
# -   [SpaCy](https://spacy.io/)
#
# A celles-ci s’ajoute des librairies de représentations graphiques
# synthétiques comme [WordCloud](https://github.com/amueller/word_cloud),
# `Gensim` et `Pywaffle`.

# %% [markdown]
# <div class="alert alert-warning" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #ffc10780;">
# <h3 class="alert-heading"><i class="fa fa-lightbulb-o"></i> Hint</h3>
#
# Comme dans la [partie précédente](#nlp), il faut télécharger quelques éléments pour que `NTLK` puisse fonctionner correctement. Pour cela, faire :
#
# ``` python
# import nltk
#
# nltk.download("stopwords")
# nltk.download("punkt")
# nltk.download("genesis")
# nltk.download("wordnet")
# nltk.download("omw-1.4")
# ```
#
# </div>

# %% [markdown]
# La liste des modules à importer est assez longue, la voici :

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import base64
import string
import re
import nltk

from collections import Counter
from time import time

# from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS as stopwords
from sklearn.metrics import log_loss
import matplotlib.pyplot as plt

#!pip install pywaffle
from pywaffle import Waffle

from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("genesis")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# C:\Users\Utilisateur\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package genesis to
# [nltk_data]     C:\Users\Utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package genesis is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ## Données utilisées

# %% [markdown]
# <div class="alert alert-success" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #3fb618;">
# <h3 class="alert-heading"><i class="fa fa-pencil"></i> Exercice 1 (optionnel): Importer les données spooky</h3>
#
# *Pour ceux qui ont envie de tester leurs connaissances en `Pandas`*
#
# 1.  Importer le jeu de données `spooky` à partir de l’URL <https://github.com/GU4243-ADS/spring2018-project1-ginnyqg/raw/master/data/spooky.csv> sous le nom `train`. L’encoding est `latin-1`
# 2.  Mettre des majuscules au nom des colonnes.
# 3.  Retirer le prefix `id` de la colonne `Id` et appeler la nouvelle colonne `ID`.
# 4.  Mettre l’ancienne colonne `Id` en index.
#
# </div>

# %% [markdown]
# Si vous ne faites pas l’exercice 1, pensez à charger les données en executant la fonction `get_data.py` :

# %%
import requests

url = "https://raw.githubusercontent.com/linogaliana/python-datascientist/master/content/NLP/get_data.py"
r = requests.get(url, allow_redirects=True)
open("getdata.py", "wb").write(r.content)

import getdata

train = getdata.create_train_dataframes()

# %% [markdown]
# Ce code introduit une base nommée `train` dans l’environnement.
#
# Le jeu de données met ainsi en regard un auteur avec une phrase qu’il a écrite :

# %%
train.head()
# Out:
#                                                       Text Author     ID
# Id
# id26305  This process, however, afforded me no means of...    EAP  26305
# id17569  It never once occurred to me that the fumbling...    HPL  17569
# id11008  In his left hand was a gold snuff box, from wh...    EAP  11008
# id27763  How lovely is spring As we looked from Windsor...    MWS  27763
# id12958  Finding nothing else, not even gold, the Super...    HPL  12958

# %% [markdown]
# On peut se rendre compte que les extraits des 3 auteurs ne sont
# pas forcément équilibrés dans le jeu de données.
# Il faudra en tenir compte dans la prédiction.

# %%
fig = plt.figure()
g = sns.barplot(
    x=["Edgar Allen Poe", "Mary W. Shelley", "H.P. Lovecraft"],
    y=train["Author"].value_counts(),
)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %% [markdown]
# <div class="alert alert-info" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #007bff80;">
# <h3 class="alert-heading"><i class="fa fa-comment"></i> Note</h3>
#
# L’approche *bag of words* est présentée de
# manière plus extensive dans le [chapitre précédent](#nlp).
#
# L’idée est d’étudier la fréquence des mots d’un document et la
# surreprésentation des mots par rapport à un document de
# référence (appelé *corpus*).
#
# Cette approche un peu simpliste mais très
# efficace : on peut calculer des scores permettant par exemple de faire
# de classification automatique de document par thème, de comparer la
# similarité de deux documents. Elle est souvent utilisée en première analyse,
# et elle reste la référence pour l’analyse de textes mal
# structurés (tweets, dialogue tchat, etc.).
#
# Les analyses tf-idf (*term frequency-inverse document frequency*) ou les
# constructions d’indices de similarité cosinus reposent sur ce type d’approche.
#
# </div>

# %% [markdown]
# ### Fréquence d’un mot
#
# Avant de s’adonner à une analyse systématique du champ lexical de chaque
# auteur, on va se focaliser dans un premier temps sur un unique mot, le mot *fear*.

# %% [markdown]
# <div class="alert alert-info" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #007bff80;">
# <h3 class="alert-heading"><i class="fa fa-comment"></i> Note</h3>
#
# L’exercice ci-dessous présente une représentation graphique nommée
# *waffle chart*. Il s’agit d’une approche préférable aux
# camemberts qui sont des graphiques manipulables car l’oeil humain se laisse
# facilement berner par cette représentation graphique qui ne respecte pas
# les proportions.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #3fb618;">
# <h3 class="alert-heading"><i class="fa fa-pencil"></i> Exercice 2 : Fréquence d'un mot</h3>
#
# 1.  Compter le nombre de phrases, pour chaque auteur, où apparaît le mot `fear`.
# 2.  Utiliser `pywaffle` pour obtenir les graphiques ci-dessous qui résument
#     de manière synthétique le nombre d’occurrences du mot *“fear”* par auteur.
# 3.  Refaire l’analyse avec le mot *“horror”*.
#
# </div>

# %% [markdown]
# A l’issue de la question 1, vous devriez obtenir le tableau
# de fréquence suivant :

# %%
word_to_search = 'fear'  # or 'horror'

# Count occurrences of the word by author
author_word_counts = train.groupby('Author')['Text'].apply(lambda x: sum(1 for text in x if word_to_search in text))

author_word_counts
# Out:
# Author
# EAP     70
# HPL    160
# MWS    211
# Name: Text, dtype: int64

# %% [markdown]
# Ceci permet d’obtenir le *waffle chart* suivant :

# %%
# Visualize using pywaffle
fig = plt.figure(
    FigureClass=Waffle,
    rows=5,
    values=author_word_counts,
    labels=list(author_word_counts.index),
    figsize=(10, 5),
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)}
)
plt.title(f'Occurrences of "{word_to_search}" by Author')
plt.show()
# Out:
# <Waffle size 1000x500 with 1 Axes>

# %% [markdown]
# On remarque ainsi de manière très intuitive
# le déséquilibre de notre jeu de données
# lorsqu’on se focalise sur le terme *“peur”*
# où Mary Shelley représente près de 50%
# des observations.
#
# Si on reproduit cette analyse avec le terme *“horror”*, on peut
# en conclure que la peur est plus évoquée par Mary Shelley
# (sentiment assez naturel face à la créature du docteur Frankenstein) alors
# que Lovecraft n’a pas volé sa réputation d’écrivain de l’horreur !

# %%
word_to_search = 'horror'  # or 'horror'

# Count occurrences of the word by author
author_word_counts = train.groupby('Author')['Text'].apply(lambda x: sum(1 for text in x if word_to_search in text))
# Visualize using pywaffle
fig = plt.figure(
    FigureClass=Waffle,
    rows=5,
    values=author_word_counts,
    labels=list(author_word_counts.index),
    figsize=(10, 5),
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)}
)
plt.title(f'Occurrences of "{word_to_search}" by Author')
plt.show()
# Out:
# <Waffle size 1000x500 with 1 Axes>

# %% [markdown]
# ### Premier *wordcloud*
#
# Pour aller plus loin dans l’analyse du champ lexical de chaque auteur,
# on peut représenter un `wordcloud` qui permet d’afficher chaque mot avec une
# taille proportionnelle au nombre d’occurrence de celui-ci.

# %% [markdown]
# <div class="alert alert-success" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #3fb618;">
# <h3 class="alert-heading"><i class="fa fa-pencil"></i> Exercice 3 : Wordcloud</h3>
#
# 1.  En utilisant la fonction `wordCloud`, faire trois nuages de mot pour représenter les mots les plus utilisés par chaque auteur.
# 2.  Calculer les 25 mots plus communs pour chaque auteur et représenter les trois histogrammes des décomptes.
#
# </div>

# %% [markdown]
# Le *wordcloud* pour nos différents auteurs est le suivant :

# %%
def generate_word_cloud(author_name):
    # Filter sentences by author
    sentences = train[train['Author'] == author_name]['Text']
    
    # Tokenize and count words
    words = ' '.join(sentences).split()
    word_counts = Counter(words)
    
    # Get the 25 most common words
    common_words = word_counts.most_common(100)
    
    # Create word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(common_words))
    
    # Plot word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud for {author_name}')
    plt.axis('off')
    plt.show()
    
unique_authors = train['Author'].unique()
for author in unique_authors:
    generate_word_cloud(author)

# %% [markdown]
# Enfin, si on fait un histogramme des fréquences,
# cela donnera :

# %%
def generate_histogram(author_name):
    # Filter sentences by author
    sentences = train[train['Author'] == author_name]['Text']
    
    # Tokenize and count words
    words = ' '.join(sentences).split()
    word_counts = Counter(words)
    
    # Get the 25 most common words
    common_words = word_counts.most_common(25)
    
    # Plot histogram
    plt.figure(figsize=(10, 5))
    plt.bar(range(len(common_words)), [count for _, count in common_words], tick_label=[word for word, _ in common_words])
    plt.title(f'Most Common Words for {author_name}')
    plt.xticks(rotation=45, ha='right')
    plt.ylabel('Count')
    plt.xlabel('Word')
    plt.show()

# Unique authors in the dataset
unique_authors = train['Author'].unique()

# Generate word cloud and histogram for each author
for author in unique_authors:
    generate_histogram(author)

# %% [markdown]
# On voit ici que ce sont des mots communs, comme *“the”*, *“of”*, etc. sont très
# présents. Mais ils sont peu porteurs d’information, on peut donc les éliminer
# avant de faire une analyse syntaxique poussée.
# Ceci est une démonstration par l’exemple qu’il vaut mieux nettoyer le texte avant de
# l’analyser (sauf si on est intéressé
# par la loi de Zipf, cf. exercice suivant).
#
# A noter que l’histogramme produit
# par le biais de `Matplotlib` ou `Seaborn` est
# peu lisible. Il vaut mieux privilégier `Plotly`
# pour faire celui-ci afin d’avoir les mots qui s’affichent en
# passant sa souris sur chaque barre.
#
# ### Aparté : la loi de Zipf

# %% [markdown]
# <div class="alert alert-warning" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #ffc10780;">
# <h3 class="alert-heading"><i class="fa fa-pencil"></i> La loi de Zipf</h3>
#
# Dans son sens strict, la loi de Zipf prévoit que
# dans un texte donné, la fréquence d’occurrence $f(n_i)$ d’un mot est
# liée à son rang $n_i$ dans l’ordre des fréquences par une loi de la forme
# $f(n_i) = c/n_i$ où $c$ est une constante. Zipf, dans les années 1930, se basait sur l’oeuvre
# de Joyce, *Ulysse* pour cette affirmation.
#
# Plus généralement, on peut dériver la loi de Zipf d’une distribution exponentielle des fréquences : $f(n_i) = cn_{i}^{-k}$. Cela permet d’utiliser la famille des modèles linéaires généralisés, notamment les régressions poissonniennes, pour mesurer les paramètres de la loi. Les modèles linéaire traditionnels en `log` souffrent en effet, dans ce contexte, de biais (la loi de Zipf est un cas particulier d’un modèle gravitaire, où appliquer des OLS est une mauvaise idée, cf. [Galiana et al. (2020)](https://linogaliana.netlify.app/publication/2020-segregation/) pour les limites).
#
# </div>

# %% [markdown]
# Un modèle exponentiel peut se représenter par un modèle de Poisson ou, si
# les données sont très dispersées, par un modèle binomial négatif. Pour
# plus d’informations, consulter l’annexe de Galiana et al. (2020).
# La technique économétrique associée pour l’estimation est
# les modèles linéaires généralisés (GLM) qu’on peut
# utiliser en `Python` via le
# package \`statsmodels\``{=html} <a name="cite_note-3"></a>3. [^](#cite_ref-3)`

# %% [raw]
# <a name="cite_note-3"></a>3. [^](#cite_ref-3)

# %% [markdown]
# La littérature sur les modèles gravitaires, présentée dans Galiana et al. (2020),
# donne quelques arguments pour privilégier les modèles GLM à des modèles log-linéaires
# estimés par moindres carrés ordinaires.
#
# $$
# \mathbb{E}\bigg( f(n_i)|n_i \bigg) = \exp(\beta_0 + \beta_1 \log(n_i))
# $$
#
# Prenons les résultats de l’exercice précédent et enrichissons les du rang et de la fréquence d’occurrence d’un mot :

# %%
count_words = pd.DataFrame(
    {
        "counter": train.groupby("Author")
        .apply(lambda s: " ".join(s["Text"]).split())
        .apply(lambda s: Counter(s))
        .apply(lambda s: s.most_common())
        .explode()
    }
)
count_words[["word", "count"]] = pd.DataFrame(
    count_words["counter"].tolist(), index=count_words.index
)
count_words = count_words.reset_index()

count_words = count_words.assign(
    tot_mots_auteur=lambda x: (x.groupby("Author")["count"].transform("sum")),
    freq=lambda x: x["count"] / x["tot_mots_auteur"],
    rank=lambda x: x.groupby("Author")["count"].transform("rank", ascending=False),
)
# Out:
# C:\Users\Utilisateur\AppData\Local\Temp\ipykernel_13180\4090456936.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda s: " ".join(s["Text"]).split())

# %% [markdown]
# Commençons par représenter la relation entre la fréquence et le rang:

# %%
from plotnine import *

g = (
    ggplot(count_words)
    + geom_point(aes(y="freq", x="rank", color="Author"), alpha=0.4)
    + scale_x_log10()
    + scale_y_log10()
    + theme_minimal()
)

# %% [markdown]
# Nous avons bien, graphiquement, une relation log-linéaire entre les deux :

# %% [markdown]
# Avec `statsmodels`, vérifions plus formellement cette relation:

# %%
import statsmodels.api as sm

exog = sm.add_constant(np.log(count_words["rank"].astype(float)))

model = sm.GLM(
    count_words["freq"].astype(float), exog, family=sm.families.Poisson()
).fit()

# Afficher les résultats du modèle
print(model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   freq   No. Observations:                69301
# Model:                            GLM   Df Residuals:                    69299
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -23.011
# Date:                Wed, 17 Apr 2024   Deviance:                     0.065676
# Time:                        09:26:33   Pearson chi2:                   0.0656
# No. Iterations:                     5   Pseudo R-squ. (CS):          0.0002431
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.4388      1.089     -2.239      0.025      -4.574      -0.303
# rank          -0.9831      0.189     -5.196      0.000      -1.354      -0.612
# ==============================================================================

# %% [markdown]
# Le coefficient de la régression est presque 1 ce qui suggère bien une relation
# quasiment log-linéaire entre le rang et la fréquence d’occurrence d’un mot.
# Dit autrement, le mot le plus utilisé l’est deux fois plus que le deuxième mot le plus fréquent qui l’est trois plus que le troisième, etc.
#
# ## Nettoyage d’un texte
#
# Les premières étapes dans le nettoyage d’un texte, qu’on a
# développé au cours du [chapitre précédent](../../content/NLP/01_intro.html), sont :
#
# -   suppression de la ponctuation ;
# -   suppression des *stopwords*.
#
# Cela passe par la tokenisation d’un texte, c’est-à-dire la décomposition
# de celui-ci en unités lexicales (les *tokens*).
# Ces unités lexicales peuvent être de différentes natures,
# selon l’analyse que l’on désire mener.
# Ici, on va définir les tokens comme étant les mots utilisés.
#
# Plutôt que de faire soi-même ce travail de nettoyage,
# avec des fonctions mal optimisées,
# on peut utiliser la librairie `nltk` comme détaillé [précédemment](../../content/NLP/01_intro.html).

# %% [markdown]
# <div class="alert alert-success" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #3fb618;">
# <h3 class="alert-heading"><i class="fa fa-pencil"></i> Exercice 4 : Nettoyage du texte</h3>
#
# Repartir de `train`, notre jeu de données d’entraînement.
#
# 1.  Tokeniser chaque phrase avec `nltk`.
# 2.  Retirer les stopwords avec `nltk`.
#
# </div>

# %% [markdown]
# Pour rappel, au début de l’exercice, `train` présente l’aspect suivant :

# %%
train.head()
# Out:
#                                                       Text Author     ID
# Id
# id26305  This process, however, afforded me no means of...    EAP  26305
# id17569  It never once occurred to me that the fumbling...    HPL  17569
# id11008  In his left hand was a gold snuff box, from wh...    EAP  11008
# id27763  How lovely is spring As we looked from Windsor...    MWS  27763
# id12958  Finding nothing else, not even gold, the Super...    HPL  12958

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

nltk.download('punkt')
nltk.download('stopwords')

# Function to tokenize and remove stopwords
def tokenize_and_remove_stopwords(sentence):
    # Tokenize sentence
    
    translator = str.maketrans('', '', string.punctuation)
    text_without_punctuation = sentence.translate(translator)
    tokens = word_tokenize(text_without_punctuation)
    
   
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
    
    # Join tokens back into a string
    filtered_sentence = ' '.join(filtered_tokens)
    
    return filtered_sentence

# Tokenize each sentence and remove stopwords
train['Text'] = train['Text'].apply(tokenize_and_remove_stopwords)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Après tokenisation, il devrait avoir cet aspect :

# %%
print(train['Text'])
# Out:
# Id
# id26305    process however afforded means ascertaining di...
# id17569           never occurred fumbling might mere mistake
# id11008    left hand gold snuff box capered hill cutting ...
# id27763    lovely spring looked Windsor Terrace sixteen f...
# id12958    Finding nothing else even gold Superintendent ...
#                                  ...
# id17718    could fancied looked eminent landscape painter...
# id08973                         lids clenched together spasm
# id05267    Mais il faut agir say Frenchman never faints o...
# id17513            item news like strikes us coolly received
# id00393    laid gnarled claw shoulder seemed shaking alto...
# Name: Text, Length: 19579, dtype: object

# %% [markdown]
# Après le retrait des stopwords, cela donnera :

# %% [markdown]
# <div class="alert alert-warning" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #ffc10780;">
# <h3 class="alert-heading"><i class="fa fa-lightbulb-o"></i> Hint</h3>
#
# La méthode `apply` est très pratique ici car nous avons une phrase par ligne. Plutôt que de faire un `DataFrame` par auteur, ce qui n’est pas une approche très flexible, on peut directement appliquer la tokenisation
# sur notre `DataFrame` grâce à `apply`, sans le diviser.
#
# </div>

# %% [markdown]
# Ce petit nettoyage permet d’arriver à un texte plus intéressant en termes d’analyse lexicale. Par exemple, si on reproduit l’analyse précédente… :

# %%
def generate_word_cloud(author_name):
    # Filter sentences by author
    sentences = train[train['Author'] == author_name]['Text']
    
    # Tokenize and count words
    words = ' '.join(sentences).split()
    word_counts = Counter(words)
    
    # Get the 25 most common words
    common_words = word_counts.most_common(100)
    
    # Create word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(common_words))
    
    # Plot word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud for {author_name}')
    plt.axis('off')
    plt.show()
    
unique_authors = train['Author'].unique()
for author in unique_authors:
    generate_word_cloud(author)

# %% [markdown]
# Pour aller plus loin dans l’harmonisation d’un texte, il est possible de
# mettre en place les classes d’équivalence développées dans la
# [partie précédente](../../content/NLP/01_intro.html) afin de remplacer différentes variations d’un même
# mot par une forme canonique :
#
# -   la **racinisation** (*stemming*) assez fruste mais rapide, notamment
#     en présence de fautes d’orthographe. Dans ce cas, *chevaux* peut devenir *chev*
#     mais être ainsi confondu avec *chevet* ou *cheveux*.
#     Cette méthode est généralement plus simple à mettre en oeuvre, quoique
#     plus fruste.
#
# -   la **lemmatisation** qui requiert la connaissance des statuts
#     grammaticaux (exemple : *chevaux* devient *cheval*).
#     Elle est mise en oeuvre, comme toujours avec `nltk`, à travers un
#     modèle. En l’occurrence, un `WordNetLemmatizer` (WordNet est une base
#     lexicographique ouverte). Par exemple, les mots *“women”*, *“daughters”*
#     et *“leaves”* seront ainsi lemmatisés de la manière suivante :

# %%
from nltk.stem import WordNetLemmatizer

lemm = WordNetLemmatizer()

for word in ["women", "daughters", "leaves"]:
    print(f"The lemmatized form of {word} is: {lemm.lemmatize(word)}")
# Out:
# The lemmatized form of women is: woman
# The lemmatized form of daughters is: daughter
# The lemmatized form of leaves is: leaf

# %% [markdown]
# <div class="alert alert-info" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #007bff80;">
# <h3 class="alert-heading"><i class="fa fa-comment"></i> Note</h3>
#
# Pour disposer du corpus nécessaire à la lemmatisation, il faut, la première fois,
# télécharger celui-ci grâce aux commandes suivantes :
#
# ``` python
# import nltk
#
# nltk.download("wordnet")
# nltk.download("omw-1.4")
# ```
#
# </div>

# %% [markdown]
# On va se restreindre au corpus d’Edgar Allan Poe et repartir de la base de données
# brute :

# %% [markdown]
# <div class="alert alert-success" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #3fb618;">
# <h3 class="alert-heading"><i class="fa fa-pencil"></i> Exercice 5 : Lemmatisation avec nltk</h3>
#
# Utiliser un `WordNetLemmatizer` et observer le résultat.
#
# Optionnel : Effectuer la même tâche avec `spaCy`
#
# </div>

# %% [markdown]
# Le `WordNetLemmatizer` donnera le résultat suivant :

# %%
lemm = WordNetLemmatizer()

sentences = train['Text']
    
# Tokenize and count words
words = ' '.join(sentences).split()
word_counts = Counter(words)

[lemm.lemmatize(word) for word in sentences]
# Out:
# ['process however afforded means ascertaining dimensions dungeon might make circuit return point whence set without aware fact perfectly uniform seemed wall',
#  'never occurred fumbling might mere mistake',
#  'left hand gold snuff box capered hill cutting manner fantastic steps took snuff incessantly air greatest possible self satisfaction',
#  'lovely spring looked Windsor Terrace sixteen fertile counties spread beneath speckled happy cottages wealthier towns looked former years heart cheering fair',
#  'Finding nothing else even gold Superintendent abandoned attempts perplexed look occasionally steals countenance sits thinking desk',
#  'youth passed solitude best years spent gentle feminine fosterage refined groundwork character overcome intense distaste usual brutality exercised board ship never believed necessary heard mariner equally noted kindliness heart respect obedience paid crew felt peculiarly fortunate able secure services',
#  'astronomer perhaps point took refuge suggestion non luminosity analogy suddenly let fall',
#  'surcingle hung ribands body',
#  'knew could say stereotomy without brought think atomies thus theories Epicurus since discussed subject long ago mentioned singularly yet little notice vague guesses noble Greek met confirmation late nebular cosmogony felt could avoid casting eyes upward great nebula Orion certainly expected would',
#  'confess neither structure languages code governments politics various states possessed attractions',
#  'shall find feel injuries shall learn dread revenge days arrived',
#  'barricaded present secure',
#  'Herbert West needed fresh bodies life work reanimation dead',
#  'farm like grounds extended back deeply hill almost Wheaton Street',
#  'glance show fallacy idea',
#  'escaped must commence destructive almost endless journey across mountainous ices ocean amidst cold inhabitants could long endure native genial sunny climate could hope survive',
#  'speeches gave course interpretation fancying doubt events come possession vast quantities ready money provided paid owed trifle consideration services dare say cared little became either soul carcass',
#  'native sprightliness needed undue excitement placid heart reposed contented love well children beauty surrounding nature',
#  'even went far speak slightly hectic cough one time troubled chronic rheumatism twinge hereditary gout conclusion disagreeable inconvenient hitherto carefully concealed weakness eyes',
#  'facial aspect remarkable maturity though shared mothers grandfathers chinlessness firm precociously shaped nose united expression large dark almost Latin eyes give air quasi adulthood well nigh preternatural intelligence',
#  'net work permanently fastened hoop attached series running loops nooses',
#  'sounds hideous held vibrations suggesting nothing globe earth certain intervals assumed symphonic quality could hardly conceive produced one player',
#  'every hand wilderness balconies verandas minarets shrines fantastically carved oriels',
#  'deep spirit wonder perplexity wont regard remote pew gallery step solemn slow ascended pulpit reverend man countenance demurely benign robes glossy clerically flowing wig minutely powdered rigid vast could late sour visage snuffy habiliments administered ferule hand Draconian laws academy',
#  'bizarre attempts explanation followed others equally bizarre',
#  'many prodigies signs taken place far wide sea land black wings Pestilence spread abroad',
#  'yet fairly said known Pure gold made readily lead connection certain substances kind proportions unknown Speculation course busy immediate ultimate results discovery discovery thinking persons hesitate referring increased interest matter gold generally late developments California reflection brings us inevitably another exceeding inopportuneness Von Kempelens analysis',
#  'seemed upon verge comprehension without power comprehend men times find upon brink remembrance without able end remember',
#  'compasses depth gauges delicate instruments ruined henceforth reckoning would guesswork based watches calendar apparent drift judged objects might spy portholes conning tower',
#  'young warriors took back Sarnath symbol conquest old gods beings Ib sign leadership Mnar',
#  'Meantime whole Paradise Arnheim bursts upon view',
#  'rich young guardian appointed would act one great society must keep secret really cut ever',
#  'could make little dim light seemed contain prophecies detailed relations events lately passed names well known modern date often exclamations exultation woe victory defeat traced thin scant pages',
#  'Even talked tombs',
#  'Sheehan especially ply inquiries yet without eliciting information value concerning Old Bugs',
#  'cried aloud little later gave gasp terrible cry',
#  'old tracks crossed River Street grade veered region increasingly rural less less Innsmouths abhorrent fishy odour',
#  'soul overflowed ardent affections friendship devoted wondrous nature world minded teach us look imagination',
#  'first start replaced tissue wrapping around portrait shield sordidness place',
#  'present peculiar condition affairs court especially intrigues known involved would render instant availability document susceptibility produced moments notice point nearly equal importance possession',
#  'Wilburs growth indeed phenomenal within three months birth attained size muscular power usually found infants full year age',
#  'Pausing succeeded difficulty raising whereupon revealed black aperture exhaling noxious fumes caused torch sputter disclosing unsteady glare top flight stone steps',
#  'mud water sky dark rain wipin aout tracks abaout fast could beginnin glen maouth whar trees moved still awful prints big barls like seen Monday',
#  'visits Merrival Windsor frequent suddenly ceased',
#  'supposed however great Underduk suffered impertinence part little old man pass impunity',
#  'need tell sceptical hitherto topic souls immortality',
#  'often compared finding chief superiority consisted power soon persuaded power inferior chiefest potentates earth',
#  'childrens children newcomers children grew',
#  'Dr Johnson beheld full pursy Man ill drest slovenly Aspect',
#  'Presently murmur water fell gently upon ear moments afterward turned road somewhat abruptly hitherto became aware building kind lay foot gentle declivity',
#  'Ellison remarkable continuous profusion good gifts lavished upon fortune',
#  'still continued plane elipse made little progress eastward',
#  'useless provide many things find abundant provision every town',
#  'fly quickly snow sledges motion pleasant opinion far agreeable English stagecoach',
#  'pointed spot disappeared followed track boats nets cast vain',
#  'indistinct recollections great storm time reached boat rate know heard peals thunder tones Nature utters wildest moods',
#  'seemed one courtyard hoped would chance get away spreading general alarm',
#  'Mein Gott take vor shicken oh replied much alarmed chicken certainly',
#  'Perpetual fear jaundiced complexion shrivelled whole person',
#  'sun set atmosphere grew dim evening star longer shone companionless',
#  'rain ceased clouds sunk behind horizon evening sun descended swiftly western sky',
#  'Nothing however occurred except hill noises day came many hoped new horror gone swiftly come',
#  'state rooms sufficiently roomy two berths one',
#  'getting dark ancient roofs chimney pots outside looked queer bulls eye window panes',
#  'marched various parts southern counties quartered deserted villages part sent back island season winter far revived energy passes country defended increase numbers prohibited',
#  'suffered little cold dampness atmosphere unpleasant ample space car enabled us lie means cloaks blankets sufficiently well',
#  'dared conquered till sold death sole condition thou shouldst follow Fire war plague unite thy destruction Raymond safety thee heavy heart listened changes delirium made bed cloaks violence decreased clammy dew stood brow paleness death succeeded crimson fever placed cloaks',
#  'seemed interior house old house apparently details inhabitants constantly changing could never certain faces furniture even room since doors windows seemed great state flux presumably mobile objects',
#  'gentleman clothed head foot richly embroidered black silk velvet pall wrapped negligently around form fashion Spanish cloak',
#  'pigeons appeared distressed extreme struggled escape cat mewed piteously tongue hanging mouth staggered fro car influence poison',
#  'window panes gone',
#  'panted gasped breath could doubt design tormentors oh unrelenting oh demoniac men shrank glowing metal centre cell',
#  'great difficulty gained feet looking dizzily around first struck idea among breakers terrific beyond wildest imagination whirlpool mountainous foaming ocean within engulfed',
#  'next morning delivered letters introduction paid visit principal professors',
#  'Raymond make end without drawing vivid glowing colours splendour kingdom opposition commercial spirit republicanism',
#  'celebrated Magazine sustain evidently tremendous expenses understand',
#  'week two visibly faded course months hardly discernible naked eye',
#  'stranger learned twenty words first lesson indeed understood profited others',
#  'people looked coming struggle would great degree decisive case victory next step would siege Constantinople Greeks',
#  'could cavity detected sounding',
#  'lieutenant instance man wonderful courage enterprise madly desirous glory rather word phrase characteristically advancement profession',
#  'Within twenty four hours machine near table generate waves acting unrecognised sense organs exist us atrophied rudimentary vestiges',
#  'Everybody got aout idee dyin excep canoe wars islanders sacrifices sea gods daown snake bite plague sharp gallopin ailments somethin afore cud take water simply looked forrad kind change want bit horrible arter',
#  'lips usual marble pallor',
#  'absolutely needless replied G',
#  'Ahead lay sparse grass scrub blueberry bushes beyond naked rock crag thin peak dreaded grey cottage',
#  'near loved feel limit desires',
#  'sky serene unable rest resolved visit spot poor William murdered',
#  'say thing observed tell Latin rem',
#  'said threw greatly shade Cornelius Agrippa Albertus Magnus Paracelsus lords imagination fatality overthrow men disinclined pursue accustomed studies',
#  'ex queen gives Idris Adrian totally unfitted succeed earldom earldom hands becomes kingdom',
#  'pupils upon accession diminution light underwent contraction dilation observed feline tribe',
#  'Keep largest branch one side said Legrand',
#  'quivering awhile among draperies room length rested full view upon surface door brass',
#  'Maternal affection rendered Idris selfish beginning calamity thoughtless enthusiasm devoted care sick helpless',
#  'came like protecting spirit poor girl committed care interment friend conducted Geneva placed protection relation',
#  'expected extravagant proposition remained silent awhile collecting thoughts might better combat fanciful scheme',
#  'Matters assumed really serious aspect resolved call upon particular friend Mr Theodore Sinivate knew least get something like definite information',
#  'system disadvantages even dangers',
#  'Everyone seemed inclined silent though holding secret fear',
#  'still appeared public together lived roof',
#  'dear fellow joking said passable skull indeed may say excellent skull according vulgar notions specimens physiology scarabÃ¦us must queerest scarabÃ¦us world resembles',
#  'vaow afur Gawd dunt know wants hes tryin dew',
#  'began answer violence Yes yes hate bane poison disgust Oh manner changed fixing eyes expression convulsed every nerve member frame none light one life',
#  'shivered wondered reach light would looked dared',
#  'slow ravages disease pleasant watch case something subtler puzzling background',
#  'Comte associates turned away lowly abode alchemists form Charles Le Sorcier appeared trees',
#  'said happened medical school West already made notorious wild theories nature death possibility overcoming artificially',
#  'Besides Perdita retirement saw moodiness succeeded forced hilarity marked disturbed sleep painful irritability seen tears scarce ceased flow since beheld big drops disappointed pride caused gather eye pride unable dispel',
#  'packed chemical instruments materials collected resolving finish labours obscure nook northern highlands Scotland',
#  'ideas friend may summed words',
#  'definite point among stars claim calling',
#  'believe shall forced call',
#  'God knows world ever glimpsed blasphemous shapes loped trotted crawled whatever baffling source images one thing plain',
#  'Yet appearances given beg pardon given learned future ages Ashimah Syrians',
#  'skin embrowned sun step firm conscious power',
#  'slums along Main Street would find old Georgian churches long abandoned',
#  'believe sir forgotten pay brandy water',
#  'started forward exclaimed Villain sign death warrant sure safe',
#  'eyes stayed whole glared propulsive dilated incandescence grew face around charred dwindled',
#  'determined extract condense glory power achievement might resulted long reign three years Protectorate',
#  'advertisement picking boat',
#  'Baffled excavators sought conference Superintendent ordered great lengths rope taken pit spliced lowered without cessation till bottom might discovered',
#  'received orders taken brought Earl lenity made expect conclusion considered ill befitting crime',
#  'lean Nith remarked one seen old man wife since night cats away',
#  'Six years elapsed passed dream one indelible trace stood place last embraced father departure Ingolstadt',
#  'Kidds accumulations immense well known',
#  'looked beheld head rise black liquid deep sunken eyes open terror thin shadowed lips part scream frightful uttered',
#  'high summits one one drop everlasting dews',
#  'spent many hours tears mournful meditation past twelve oclock peace house gentle air stole window rustle leaves twining plants shadowed',
#  'traditionally receptive ears small boy learned much though habitual secretiveness caused tell one information resolve',
#  'understand words know certain things made feel certain emotions fancied unremembered dream must responsible',
#  'Look weep two years never enjoyed one moment free anguish',
#  'indeed demonstrable every impulse given air must end impress every individual thing exists within universe infinite understanding imagined might trace remote undulations impulse trace upward onward influences upon particles matter upward onward ever modifications old forms words creation new found reflected unimpressive last back throne Godhead',
#  'Justine called defence',
#  'engagement broken Galpin moved east begin life anew long Appletonians heard dismissal disgrace New York University obtained instructorship English',
#  'narrow head bulging watery blue eyes seemed never wink flat nose receding forehead chin singularly undeveloped ears',
#  'remembered earliest stage speculations upon possibility passage moon existence vicinity atmosphere dense proportion bulk planet entered largely calculations spite many theories contrary may added spite general disbelief existence lunar atmosphere',
#  'words flowed spontaneously utterance firm quick',
#  'rare affliction course could bring vast radical anatomical changes single individual maturity changes involving osseous factors basic shape skull even aspect baffling unheard visible features malady whole',
#  'fled accursed castle along bogs edge heard new sound common yet unlike heard Kilderry',
#  'try navigate first bold flight reaction taken something soul',
#  'bear attempting swim Lofoden Moskoe caught stream borne roared terribly heard shore',
#  'obeyed injunctions passed year exile Cumberland',
#  'reverted past life successes Greece favour home',
#  'Murderers casting would failed attach weight',
#  'short inevitable sleep seemed older whilst friend aged rapidity almost shocking',
#  'look hands executed deed think heart imagination conceived long moment hands meet eyes imagination haunt thoughts',
#  'Horrible sights shaped turbid cloud hovered city relief derived struggles made approach gate',
#  'order reach said would soar abysses emptiness burning every obstacle stood way',
#  'Pierre Moreau tobacconist deposes habit selling small quantities tobacco snuff Madame LEspanaye nearly four years',
#  'still quickened pace',
#  'resolved fly far scene misfortunes hated despised every country must equally horrible',
#  'spirit wisdom among ancient Hebrews believed gates Heaven would inevitably opened sinner saint good lungs implicit confidence vociferate word Amen spirit wisdom great plague raged Athens every means vain attempted removal Epimenides Laertius relates second book philosopher advised erection shrine temple proper God LYTTLETON BARRY',
#  'feel confident never would dreamed taking residence Alexander Great nopolis aware Alexander Great nopolis lived gentleman named John Smith rightly remember many years quietly grown fat editing publishing Alexander Great nopolis Gazette',
#  'protect first latter commit charge',
#  'Miserable may render wretched ought die',
#  'police heard shot old Tillinghast house found us Tillinghast dead unconscious',
#  'even possible train ideas would never received fatal impulse led ruin',
#  'entered army initiative rather natural result enlistment man whose indispensable assistant celebrated Boston surgical specialist Dr Herbert West',
#  'last link chapter life forever closed valued highly',
#  'longer meditated upon intense grew interest excited within',
#  'often repined trust singleness affection undisturbed together unchecked fear opened heart fullest delight',
#  'nothing grotesque bones skeletons strowed stone crypts deep among foundations',
#  'full thought remained silent considerable part ride length said must apologize abstraction truth Rylands motion comes night considering reply',
#  'Thing described language abysms shrieking immemorial lunacy eldritch contradictions matter force cosmic order',
#  'add dilemma found pumps choked nearly useless',
#  'means ignorant men found little difficulty gaining purpose',
#  'queer damnably queer uncle spoke almost sheepishly half expecting believed declared strange faces many unmistakably borne features Harris family',
#  'three months night passed greater part engaged personally ransacking Hotel',
#  'Raymond wonder thus situated artist shrunk notice alter resolve',
#  'long magic farther hills sigh secrets peer like green reefs bottomless sea',
#  'endured punishment pain defence spirit hero claimed reward praise obedience',
#  'must collect thoughts',
#  'Never imposing upon one suffered one play possum',
#  'said though confess thoughts occupied pleasantly',
#  'remained paralysed fear found voice dying breath screamed forth words ever afterward haunted days nights',
#  'Surely custom Englishmen receive strangers inhospitably',
#  'remained confined five months trial took place result deprived fortune condemned perpetual exile native country',
#  'never stopped swimmin aout river cursed reef Satan attic winders got boarded noises heerd haouses want sposed hev nobody em',
#  'Lawrence prominent mock fraternity Tappa Tappa Keg wildest merriest wild merry young roysterers immature collegiate frivolity satisfy',
#  'limbs save black fur roughly resembled hind legs prehistoric earths giant saurians terminated ridgy veined pads neither hooves claws',
#  'enticements sufficient conquer fear danger death induce commence laborious voyage joy child feels embarks little boat holiday mates expedition discovery native river',
#  'adequate bolts two lateral doors connecting rooms proceeded fasten',
#  'supposition well taught boy thin tall age sufficiently could concealed drawer almost immediately chess board played game chess effected evolutions Automaton',
#  'Interspersed room crossing recrossing endless irregularity innumerable benches desks black ancient time worn piled desperately much bethumbed books beseamed initial letters names full length grotesque figures multiplied efforts knife entirely lost little original form might portion days long departed',
#  'manly courage resistance save us saved',
#  'silver hair benevolent countenance aged cottager reverence gentle manners girl enticed love',
#  'commenced inuring body hardship',
#  'absurdities must pause detail',
#  'travelled night fearful encountering visage human',
#  'Scarcely recovered senses foretopsail went shreds got storm stay sail pretty well hours ship heading sea much steadily',
#  'lower portion hidden view head unwieldy bedstead thrust close',
#  'Adrian introduced systematic modes proceeding metropolis unable stop progress death yet prevented evils vice folly rendering awful fate hour still tremendous',
#  'quarter past eight longer able draw breath without intolerable pain proceeded forthwith adjust around car apparatus belonging condenser',
#  'professor stricken whilst returning Newport boat falling suddenly witnesses said jostled nautical looking negro come one queer dark courts precipitous hillside formed short cut waterfront deceaseds home Williams Street',
#  'Suddenly wretch animated last burst strength raised hideous head damp sunken pavement',
#  'Ha ha ha said gentleman hi hi hi ho ho ho hu hu hu hu good indeed must astonished mon ami friend wit drole must understand letter',
#  'true may find opportunity transmitting world fall make endeavour',
#  'repeat landscape arrangements collocations alone physical Nature susceptible exaltation therefore susceptibility improvement one point mystery hitherto unable solve',
#  'also cut timber began repair unused parts house spacious peaked roofed affair whose rear end buried entirely rocky hillside whose three least ruined ground floor rooms always sufficient daughter',
#  'meantime folly grieve think',
#  'extreme darkness stage whose light received fire cauldron joined kind mist floated rendered unearthly shapes witches obscure shadowy',
#  'Sheehans acknowledged centre Chicagos subterranean traffic liquor narcotics certain dignity extends even unkempt attachÃ©s place lately one lay outside pale dignity one shared squalor filth importance Sheehans',
#  'Perhaps gradation copy rendered readily perceptible possibly owed security master air copyist disdaining letter painting obtuse see gave full spirit original individual contemplation chagrin',
#  'perhaps effect surroundings mind early acquired shade melancholy',
#  'ought hear though old timers tell black reef coast Devil Reef call',
#  'prince provided appliances pleasure',
#  'week tasted full joys charnel conviviality must describe thing happened borne away accursed abode sorrow monotony',
#  'see enough tell ye Mis Corey dunt mean good think men folks ought git party suthin',
#  'recognised school sculpture animated terrible object yet centuries even thousands years seemed recorded dim greenish surface unplaceable stone',
#  'long time dared hope unobstructed breathing moisture suffused forehead tokens longer mistaken departure mortal malady ventured whisper news change Idris length succeeded persuading spoke truth',
#  'comprehended moreover true character august aims supreme majesty dignity poetic sentiment',
#  'Else immortality man',
#  'laid second tier third fourth heard furious vibrations chain',
#  'became disconcerting even gruesome companion yet gratitude healing could well abandon strangers around careful dust room attend needs day muffled heavy ulster bought especially purpose',
#  'longed love filled overflowing',
#  'lambent glow sort always played old woman small furry thing lighter sharper dreams prefaced plunge unknown abysses thought wakeful second person could see dream luminance utterly beyond sane harbourage',
#  'first thought Perdita must return must support drawing food despair might best sustain wounded heart recalling wild excesses grief austere laws duty soft tenderness regret',
#  'owned affinity mankind nature akin mountains sky friends winds heaven offspring earth playmates focus mighty mirror felt life mingle universe existence',
#  'Uninquiring souls let occurrence pass one major clashes spasmodic war liquor',
#  'rigging found ill fitted greatly strained third day blow five afternoon mizzen mast heavy lurch windward went board',
#  'Alfred stood immoveable whole attention absorbed',
#  'Beyond rusted railway Rowley road led flat marshy terrain dotted islets higher dryer scrub grown land',
#  'Williamson records traditions supplied abundance grandfather though Orne material depend uncle Walter put disposal contents files including notes letters cuttings heirlooms photographs miniatures',
#  'closer scrutiny however satisfied intended kid Ha ha said sure right laugh million half money serious matter mirth establish third link chain find especial connexion pirates goat pirates know nothing goats appertain farming interest',
#  'cause wonder surely even gang blackguards make haste get home wide river crossed small boats storm impends night approaches',
#  'connexion two events much palpable true wonder would failure populace appreciate seize',
#  'heard fears driven people Kilderry laughed loudly friend laughed fears vaguest wildest absurd character',
#  'Leave inexorable',
#  'listened father silence remained time incapable offering reply',
#  'hate abhorrence equal regard',
#  'albeit without definite reason instinctively guard advantage new real crisis whatever might turn',
#  'assured patron perfectly resigned task playing Thomas Hawk',
#  'large bruise discovered upon pit stomach produced apparently pressure knee',
#  'Mem hell answer',
#  'Let composition defective let emendation wrought mere arrangement form let emendation submitted every artist world necessity admitted',
#  'hangman however adjusted noose neck',
#  'utter horrifying suddenness heard frightful sound',
#  'boat however must detained',
#  'started four oclock Legrand Jupiter dog',
#  'maps records guide books really tell North End Bah guess Ill guarantee lead thirty forty alleys networks alleys north Prince Street arent suspected ten living beings outside foreigners swarm',
#  'would useless describe playing Erich Zann dreadful night',
#  'particular instance understood probable proceeded upon route average diversity accustomed ones',
#  'noticed particulars others turned eyes upon glorious prospect soon became absorbed contemplation',
#  'Many vessels fired signal guns saluted loud cheers heard surprising distinctness waving caps handkerchiefs',
#  'party spread hurried room room',
#  'made vow love train struggles disappointment remorse sought mere sensual enjoyment remedy injurious inroads passion',
#  'Johansen brooded idol cabin attended matters food laughing maniac side',
#  'latter examined carefully deposited pocket book unlocking escritoire took thence letter gave Prefect',
#  'retired early full dread long time could sleep uncanny silence tower',
#  'provided sum money together jewels belonged mother departed',
#  'rushed towards window drawing pistol bosom fired eluded leaped station running swiftness lightning plunged lake',
#  'Xh pxh pxh Jxhn dxnt dx sx Yxuve gxt tx gx yxu knxw sx gx xnce dxnt gx slxw fxr nxbxdy xwns yxu yxu knxw',
#  'would sworn writer born brought coffin',
#  'prodigious number stately palaces',
#  'might heard return London visit Bolters Lock connected continued absence might tend greatly alarm',
#  'man whose name Beaufort proud unbending disposition could bear live poverty oblivion country formerly distinguished rank magnificence',
#  'found side humid pathway dry land sole foot',
#  'dare ask think right may still misled passion',
#  'Refusing flee watched fade watched felt turn watching greedily eyes imaginable visible',
#  'soon possible soon dark see',
#  'Since must object indifference contempt better far better avoid expose scornful world chance playing mad game fond foolish Icarus',
#  'shewed dangers children incurred absence length agreed go beyond inclosure forest',
#  'entire surface metallic enclosure rudely daubed hideous repulsive devices charnel superstition monks given rise',
#  'scene must corresponded sealed loft overhead begun attack imagination violently later impressions faint hazy',
#  'Mille tonnerres ejaculated Prince de Grenouille',
#  'remains half finished creature destroyed lay scattered floor almost felt mangled living flesh human',
#  'plain owner come home come land balloon airship could imagined',
#  'Others thought still think hed found old pirate cache Devil Reef',
#  'saw glass thin dark man medium stature attired clerical garb Anglican church apparently thirty rimless steel bowed glasses glistening beneath sallow olive forehead abnormal height',
#  'kindly influence ceased act found fettered grief indulging misery reflection',
#  'sailor looked gigantic animal seized Madame LEspanaye hair loose combing flourishing razor face imitation motions barber',
#  'feelings forever stretch begins sink repose finds obliged quit rests pleasure something new engages attention also forsakes novelties',
#  'father Safie cause ruin',
#  'matter impossible',
#  'said Baron turning abruptly toward speaker dead say indeed true lord noble name imagine unwelcome intelligence',
#  'length one escaping sewer gave freedom rest',
#  'children said firmest hopes future happiness placed prospect union',
#  'mean line Perdidit antiquum litera sonum',
#  'establishing Tea Pot expected field',
#  'would left nothing behind number would enabled carry',
#  'Time place circumstances rendered matter beyond question',
#  'developed strange caprices acquiring fondness exotic spices Egyptian incense till room smelled like vault sepulchred Pharaoh Valley Kings',
#  'made special effects indeed wrought fluid special impulses subject exact calculation became easy determine precise period impulse given extent would engirdle orb impress ever every atom atmosphere circumambient',
#  'yes reason despair',
#  'Haowd ye like hear comes awful reef every May Eve Hallowmass',
#  'alienists listened keen attention words since curiosity aroused high pitch suggestive yet mostly conflicting incoherent stories family neighbours',
#  'must midnight least Birch decided could get transom',
#  'win shall deny grief know secret pour balm soul shall enjoy ravishing delight beholding smile seeing eyes beam pleasure least gentle love thankfulness',
#  'must careful give thing downright improviso air',
#  'uncle began slowly grudgingly unwrap things urged shocked strangeness frequent hideousness designs',
#  'looked subtle curious sense beckoning seemed superadded grim repulsion oddly enough found overtone disturbing primary impression',
#  'curious although differed widely mass Hispanicised tribal Indians Romero gave least impression Caucasian blood',
#  'Ferdinand Fitz Fossillus Feltspar',
#  'termination sentence started moment paused appeared although concluded excited fancy deceived appeared remote portion mansion came indistinctly ears might exact similarity character echo stifled dull one certainly cracking ripping sound Sir Launcelot particularly described',
#  'indications afforded barometer find ascensions surface earth height feet left us one thirtieth entire mass atmospheric air ascended nearly one third far elevation Cotopaxi surmounted one half material events one half ponderable body air incumbent upon globe',
#  'task seemed interminable raged almost violently hermit saw hours slipping breathless foodless round vain telephoning hectic quest place place hither thither subway surface car',
#  'soon arrived hut door ajar',
#  'great great grandmother',
#  'moment almost paralized fear energy returned demanded guide accompany following steps',
#  'could pleasure destroyed cottage inhabitants glutted shrieks misery',
#  'breathed longer',
#  'existing moon',
#  'diminutive head gilded hair',
#  'child born alive house century half',
#  'September approached clouds began clear',
#  'remembered one harshest moments quotation mine roused anger disdain',
#  'adaptation eyes behold upon earth',
#  'times screams became insupportable long periods would utter shrieking horrors necessitated sons temporary residence cousin Peleg Harris Presbyterian Lane near new college building',
#  'nothing like order arrangement',
#  'pictorial carving however hold spellbound',
#  'grave deep fully good previous specimen thing risen uttered sound',
#  'two hours occurrence heard ground sea night ice broke freed ship',
#  'Accordingly sooner seated card table pretty hostess vis Ã vis propounded questions solution become matter essential peace',
#  'company followed example without stint',
#  'pursue guesses right call since shades reflection upon based scarcely sufficient depth appreciable intellect since could pretend make intelligible understanding another',
#  'daughter lay prostrate motionless swooned',
#  'abysses means vacant crowded indescribably angled masses alien hued substance appeared organic others seemed inorganic',
#  'Past churchyard houses could see hills summit watch glimmer stars harbour though town invisible dark',
#  'Whenever fell upon blood ran cold degrees gradually made mind take life old man thus rid eye forever',
#  'Upon occasion driven sea spite everything whirlpools threw us round round violently length fouled anchor dragged drifted one innumerable cross currents day gone morrow drove us lee Flimen good luck brought',
#  'Disappointment sickness hitherto held dominion twin born would ever enchained shall tyrants',
#  'perfume nostrils died away',
#  'Adrian led troops',
#  'tension part became great',
#  'Yet smiled still uncomplainingly saw painter high renown took fervid burning pleasure task wrought day night depict loved yet grew daily dispirited weak',
#  'earth unwittingly felt distant presence without knowing idly gave blinking beacon name Algol Daemon Star',
#  'string nerves renew wearied efforts ah',
#  'furtive trying bolted connecting door receding creaking',
#  'sun arose sickly yellow lustre clambered degrees horizon emitting decisive light',
#  'weather cold upon quitting room thrown cloak dressing wrapper putting upon reaching scene play',
#  'much reward offered say asked Dupin',
#  'still alone much feared unknown horror sought fear thought telling anybody',
#  'weep sigh must reason force feel sorrow despair',
#  'conversation long earnest uninterrupted totally unreserved',
#  'knew things didnt dare put stupid Magnalia puerile Wonders Invisible World',
#  'Briden looked back went mad laughing shrilly kept laughing intervals till death found one night cabin whilst Johansen wandering deliriously',
#  'Moreover occupations always made chime ordinary habitudes fellowmen',
#  'man Iranon spoke many others Canst thou tell may find Aira city marble beryl flows hyaline Nithra falls tiny Kra sing verdant valleys hills forested yath trees',
#  'misanthropic said locale would suit',
#  'childhood shunned house vacant barren gnarled terrible old trees long queerly pale grass nightmarishly misshapen weeds high terraced yard birds never lingered',
#  'found name good passport preferment procured situation private secretary Ambassador Vienna enter career best auspices',
#  'reasons would glad let war separate us reasons found practice medicine companionship West irritating gone Ottawa colleagues influence secured medical commission Major could resist imperious persuasion one determined accompany usual capacity',
#  'claim pity redress determined seek justice vainly attempted gain wore human form',
#  'strove think grandeur glaring infamy planting gold enwoven flag beside tarnished tattered banner proclaimed superiority debasement',
#  'dwell longer need disastrous circumstances',
#  'Geographically lay two miles northwest base Tempest Mountain three miles oak girt mansion',
#  'replied Dupin desperate man man nerve',
#  'Upon honor said Nose asked',
#  'heard next morning steward upon arrival terrible state mind passed first night garden lying damp grass sleep groaned perpetually',
#  'lock connecting door room softly tried',
#  'probably done view arousing sleep',
#  'moment eyes mine also fell upon scrap parchment supposed paper',
#  'throat marks murderous hands left ankle distressing rat bite',
#  'Everything related bears reference accursed origin whole detail series disgusting circumstances produced set view minutest description odious loathsome person given language painted horrors rendered mine indelible',
#  'reached tree Legrand turned Jupiter asked thought could climb',
#  'gave pretty nearly account former pursuits given fellow professor',
#  'Thus left ponder human creature within great fortress utter solitude mind began cease vain protest impending doom become almost reconciled fate many ancestors met',
#  'music went ideas seemed quit mortal dwelling house shook pinions began flight sailing placid current thought filling creation new glory rousing sublime imagery else slept voiceless',
#  'waited letters feverish impatience delayed miserable overcome thousand fears arrived saw superscription Elizabeth father hardly dared read ascertain fate',
#  'madness hypocrisy doubt',
#  'even acute moment chief horror something apart immediate weakness defences',
#  'Trade fallin mills losin business even new ones best menfolks kilt privateerin War lost Elizy brig Ranger snow em Gilman venters',
#  'One fine February day sun reassumed genial power walked forest family',
#  'Ingenuity diddler ingenious',
#  'reef swimmin harbour Manuxet',
#  'time Lord Raymond returned Greece',
#  'Bread water tame blood solitary confinement inspire gentle thoughts',
#  'moons distance earth round numbers miles',
#  'carried pistols dagger constantly ever watch prevent artifice means gained greater degree tranquillity',
#  'accident loss insurance serious loss hair whole singed fire predisposed serious impressions finally made mind take wife',
#  'crossed direct line vision affected forms upon passing side images impressed idea shrieks groans dismal expressions terror horror wo',
#  'entirely secluded fact inaccessible except series accidents entrance ravine means impossible indeed first adventurer first sole adventurer ever penetrated recesses',
#  'ceasing departed abruptly entered',
#  'one led way clad ghoulishly humped black coat striped trousers mans felt hat perched shapeless thing answered head',
#  'could understand say could understood notion primum mobile ever obtruded could understood manner might made objects humanity either temporal eternal',
#  'event circumstances tremendous existence subterranean space mad theories terrible confirmation',
#  'gentle words Agatha animated smiles charming Arabian',
#  'Alas Life obstinate clings closest hated',
#  'voice however still puzzled little even apparent mystery speedily cleared',
#  'Gilmans dreams consisted largely plunges limitless abysses inexplicably coloured twilight bafflingly disordered sound abysses whose material gravitational properties whose relation entity could even begin explain',
#  'struck improvement appeared health Adrian',
#  'better sir said',
#  'Another woman confirmed account fishermen brought body house cold',
#  'could find room doubt evidence senses seldom called subject wonder extent human credulity smile vivid force imagination hereditarily possessed',
#  'appearance different ever seen flight somewhat surprised',
#  'thy creature even mild docile natural lord king thou wilt also perform thy part thou owest',
#  'insane yarn heard aged drunkard promise pleasant dreams felt must keep image wild watery eyes far possible imagination',
#  'divesting clothes reason die born threw headlong current sole witness fate solitary crow seduced eating brandy saturated corn staggered away fellows',
#  'wave hand deliverers hurried tumultuously away',
#  'seen',
#  'midst continuous braying donkey arose',
#  'none exotic technique see Sidney Sime none trans Saturnian landscapes lunar fungi Clark Ashton Smith uses freeze blood',
#  'Arthur Munroe dead',
#  'doubt tranquillity family circle Windsor would recover degree composure end happiness',
#  'Great Old Ones Castro continued composed altogether flesh blood',
#  'thus fathomed satisfaction intentions Jehovah intentions built innumerable systems mind',
#  'man could crush butterfly wheel better effect man better cover speedy retreat powerful adversary',
#  'fact write upon theme necessary hanged',
#  'still apparent union permitted much woman could end present remedy encreasing negligence Protector seized paroxysm insanity trampled ceremony order duty gave license',
#  'old woman began turn toward fled precipitately bridge shelter towns labyrinthine waterfront alleys',
#  'rooks cawed loudly trees mixed hoarse cries heard lively strain music',
#  'took queer old brick well cellar one sort told',
#  'sympathy may ever find',
#  'Steeped misery misery alas real shall pardoned seeking relief however slight temporary weakness rambling details',
#  'suppose astonishment exhibited countenance Mr Kirwin hastened say Immediately upon taken ill papers person brought examined might discover trace could send relations account misfortune illness',
#  'knew deeper vices books longed know first hand',
#  'soon morning dawned crept kennel might view adjacent cottage discover could remain habitation found',
#  'Ass said fourth',
#  'Elinor die frenzy miserable despair die near',
#  'spoken advance quest felt uncles going would understand assist vitally necessary public explanations',
#  'talk subjects unconnected emotions evidently occupied divined others thought voices spoke indifferent matters eyes mute language told thousand things tongue could uttered',
#  'sorry dislike see German suffer good man die',
#  'smell awful like araound Wizard Whateleys ol haouse',
#  'Adrian instruct cold truths history philosophy',
#  'relieves us doubt upon question whether old lady could first destroyed daughter afterward committed suicide',
#  'certain rainy afternoon illusion seemed phenomenally strong addition fancied glimpsed kind thin yellowish shimmering exhalation rising nitrous pattern toward yawning fireplace spoke uncle matter',
#  'Let go cried monster Ugly wretch wish eat tear pieces',
#  'open air alone found relief among natures beauteous works God reassumed attribute benevolence could trust built mountains planted forests poured rivers would erect another state lost humanity might awaken affections happiness faith',
#  'Accordingly kept north along Main Martin turning inland crossing Federal Street safely north Green entering decayed patrician neighbourhood northern Broad Washington Lafayette Adams Streets',
#  'Bolton prevailing spirit Puritanism outlawed sport boxing usual result',
#  'went open light heart fear',
#  'reason priori diddle would diddle without grin',
#  'Vase thought vase brimful despairs direst essence',
#  'alluded Adrian spoke disparagement worldly wise always attach enthusiasm',
#  'recollected threat resolved accomplished',
#  'Raymond evidently vacillated journey irresolution marked every gesture entered Perditas cottage',
#  'spoke word worlds could uttered syllable',
#  'somewhat thick ankles fine pair green stockings cover',
#  'Thus Mark Antony composed treatise upon getting drunk',
#  'Yet fellow got odd notion',
#  'night would alone would company persons calm',
#  'P comprehend',
#  'father arrived storm already begun refused stop leaving horse walked towards sea',
#  'persistence among simple people quite natural view sudden permanent return abundantly fine fishing soon came greatest influence town replacing Freemasonry altogether taking headquarters old Masonic Hall New Church Green',
#  'inserted whole unopened wooden box closed door started electricity',
#  'islands longer visible whether passed horizon southeast whether increasing elevation left sight impossible say',
#  'dreams meanwhile increasing vividness though shewing none strange cities incredible gardens old days assuming definite cast whose purpose could mistaken',
#  'Alas become us',
#  'relatives Earl Windsor said haughtily doubtless think injured perhaps Earl would first acquit probably deserve acquittal',
#  'baying dead fleshless monstrosity grows louder louder stealthy whirring flapping accursed web wings circles closer closer shall seek revolver oblivion refuge unnamed unnamable',
#  'discover repetitions letters arranged probably represent word Upon inspection find less seven arrangements characters',
#  'careered round round perhaps hour flying rather floating getting gradually middle surge nearer nearer horrible inner edge',
#  'demeanour sad moment appeared glad see checked unwilling betray feelings',
#  'wound consequent inability Argyropylo caused Raymond first command',
#  'length pulled away',
#  'corpse found garters missing girl found shoes bonnet flowers bonnet feet peculiar mark upon arm general size appearance corpse collectively',
#  'Dr Wests reanimated specimens meant long existence large audience',
#  'often wished permitted take course engage labours welfare others might distracted thoughts',
#  'lowered without difficulty although miracle prevented swamping touched water',
#  'proceed stairs',
#  'old woman always appeared thin air near corner downward slant met inward slant',
#  'vortices complete alienage saw Brown Jenkin',
#  'beware silent urge destruction',
#  'open book lay flat us picture staring repulsively upward',
#  'motioned continue renewed signs reluctance',
#  'went resolution disputing foe',
#  'seen pp illustrious chemist conceived idea question actually made inconsiderable progress experimentally identical analysis triumphantly brought issue Von Kempelen although makes slightest allusion without doubt say unhesitatingly prove required indebted Diary least first hint undertaking',
#  'Valence knew Marie could mistaken identity',
#  'fight enemy last',
#  'repeat half felt never intellectually believed',
#  'merely crass fibre function thoughtless careless liquorish easily avoidable accident proves without modicum imagination holds average citizen within certain limits fixed taste',
#  'nobody contrive expeditious mode progress',
#  'spoke without much heed conclusion said brought thoughts',
#  'exception found person scholar although relation bore Christian surname circumstance fact little remarkable notwithstanding noble descent mine one everyday appellations seem prescriptive right time mind common property mob',
#  'reposed beside beloved tomb inscribed united names Raymond Perdita',
#  'meant one could quite certain till later',
#  'story plain plain distinct remorse horror darted fangs',
#  'also sorry one converse',
#  'saw unnerved surprisingly considering relative triviality',
#  'SIR common friend Mr P received note evening',
#  'wept would gaze silence longer harsh although repulsed every caress yet gentleness',
#  'indeed early continued musingly cherub heavy golden hammer made apartment ring first hour sunrise indeed early matters',
#  'sounds mingled roaring sea splash chafed billows round vessels sides gurgling water hold',
#  'entered brush grown cut struggling along slow pace damnable fishy odour waxed dominant',
#  'could discover amidst repinings deep resentment towards Raymond unfading sense injury plucked hope appeared nearest fulfilment',
#  '',
#  'rode town visiting wounded giving orders necessary siege meditated',
#  'box three feet half long three feet broad two half feet deep',
#  'every motion undoubtedly watched',
#  'experience West dropped researches time zeal born scientist slowly returned became importunate college faculty pleading use dissecting room fresh human specimens work regarded overwhelmingly important',
#  'Eternal night continued envelop us unrelieved phosphoric sea brilliancy accustomed tropics',
#  'Shocking said youth calmly turned quietly chateau',
#  'altogether fact predominant self assumed arms masque callous feeling haughty lady disdained exhibit token struggle endured slave pride fancied sacrificed happiness immutable principle',
#  'police laid bare floors ceilings masonry walls every direction',
#  'Uprearing tall slender lines light thus remained burning pallid motionless mirror lustre formed upon round table ebony sat us assembled beheld pallor countenance unquiet glare downcast eyes companions',
#  'Evidently ticket agent exaggerated dislike local people bore toward Innsmouth denizens',
#  'Holborn passed public house filled uproarious companions whose songs laughter shouts sorrowful pale looks silence mourner',
#  'awake like die matter',
#  'rambled oppressed distracted painful emotions suddenly found Drury Lane Theatre',
# ...
#  'gambols looked paper speak truth found little puzzled friend depicted',
#  'discussions going subject gradually approached growing larger apparent diameter brilliant lustre',
#  'stole first ones twos larger companies unimpeded officers whole battalions sought road led Macedonia',
#  'scenery judged ordinary aesthetic canon commonly beautiful yet influx artists summer tourists',
#  'glad loved experienced sympathetic joy sorrow fellow creatures',
#  'trees lithe mirthful erect bright slender graceful eastern figure foliage bark smooth glossy parti colored',
#  'Scarcely less savage Lollipop thus discoursed individual rejoices appellation Oppodeldoc low uses names illustrious dead often applied enclosed us fifty sixty verses commencing fashion Achilles wrath Greece direful spring woes unnumbered c c c c Oppodeldoc whoever respectfully informed printers devil office daily habit composing better lines',
#  'wholly alone first act walk balustrade look dizzily endless Cyclopean city almost two thousand feet',
#  'went offered services',
#  'lacked something lacked longer yet fear hatred ignorance still brood Street many stayed behind many strangers come distant places ancient houses',
#  'perceived unhealthy sharpness despite fact two senses violently assailed',
#  'admitted principles laid best denied ones',
#  'fearfully inconceivably hideous Evil proceeded Good excess wrought spirit inevitable revulsion',
#  'time shall softened despair new dear objects care born replace cruelly deprived',
#  'could suspected thing behold',
#  'One fragile mirrors ever doted thine image broken crumbled dust',
#  'recall regard common flashlight indeed common flashlight another pocket',
#  'One popular pieces mechanism seen Magician constructed Maillardet purpose answering certain given questions',
#  'strange furtive creature constantly looked shoulder afraid something sober could persuaded talk strangers',
#  'Calderon de la Barca',
#  'expect either thought thoroughly forewarned regarding jewellery would turn',
#  'detained three days longer hastened',
#  'describe sorrow felt must feel',
#  'paused reflected story tell',
#  'Ruined castles hanging precipices piny mountains impetuous Arve cottages every peeping forth among trees formed scene singular beauty',
#  'weep wiped perspiration brow tried still brain heart beating almost madness',
#  'steps many led narrow stone flagged passage knew must far underground',
#  'already decided abandon quest lurking fear rash ignorance seemed uncertainty worse enlightenment however terrible latter might prove',
#  'lost great measure deep tint blue hitherto worn grayish white lustre dazzling eye',
#  'went cold blood heart often sickened work hands',
#  'door marked remembered still open',
#  'hired chaise four horses drove speed storm',
#  'Remember dealing hideous world practically helpless',
#  'various tales aged Soames family butler ample coherent',
#  'Rome Carnival attended masquerade palazzo Neapolitan Duke Di Broglio',
#  'Thus talked moralized diminished numbers returned Windsor Castle',
#  'mournful influence unperceived shadow caused feel although neither saw heard feel presence head within room',
#  'bright light pervades cupboard body man would discovered',
#  'Asia banks Nile shores Caspian Hellespont even sea Oman sudden panic driven',
#  'wholesome landscape dark believe would noticed morbidity even ignorant terror stalked',
#  'always knew scientist Trembling eh Trembling anxiety see ultimate things discovered',
#  'yield entreaties may add pleadings bosom would entitled demand little boon return',
#  'wholly disagree theoretically yet held vague instinctive remnants primitive faith forefathers could help eyeing corpse certain amount awe terrible expectation',
#  'Idris affectionate wife sister friend tender loving mother',
#  'motion whatever nature creates',
#  'next night without daring ask rudder removes',
#  'dear Frankenstein continued stopping short gazing full face remark ill appear thin pale look watching several nights',
#  'shrieked',
#  'first assured boundless confidence must conscious since would seek detain',
#  'Wild visions opium engendered flitted shadow like',
#  'Upon entering thrust furiously',
#  'tread heavy yet seemed contain curious quality cautiousness quality disliked tread heavy',
#  'Besides estates contiguous long exercised rival influence affairs busy government',
#  'employ year admirers thrown info confusion sudden disappearance shop',
#  'apparently strangled sign violence except black mark fingers neck',
#  'rat saw skulking hole',
#  'Abhorred monster Fiend thou art tortures hell mild vengeance thy crimes',
#  'Razor hand fully lathered sitting looking glass attempting operation shaving doubt previously watched master key hole closet',
#  'resume question mere allusion revolting details surgeon examined inquest',
#  'Ah let see Let remember Yes full easily call mind precise words dear promise made Eugenie last night',
#  'partook less transport calm enthusiasm enthusiastic repose',
#  'hearing incredible popping fizzing champagne discovered length proceeded person performed bottle delicate drink dinner',
#  'topography throughout even professing accord Blunts Lunar Chart entirely variance lunar chart even grossly variance',
#  'Vell Monsieur said surveying great apparent astonishment moments Vell Monsieur',
#  'must changed',
#  'Agatha listened respect eyes sometimes filled tears endeavoured wipe away unperceived generally found countenance tone cheerful listened exhortations father',
#  'Madness rides star wind',
#  'Nothing could magnificent',
#  'capital system indeed simple neat trouble fact delicious',
#  'Still felt sure would come last wider breach might appear crisis secure closing ever',
#  'Well Bobby boy youre fine fellow arent',
#  'dream saw shoggoth first time sight set awake frenzy screaming',
#  'oven instance good hit',
#  'yet never better health',
#  'agreed call whole thing chemical laboratory discovery occur',
#  'left employment Messrs Cut Comeagain set Eye Sore line one lucrative respectable independent ordinary occupations',
#  'imagined habitual endurance atmospheric pressure surface earth cause nearly pain attending animal existence distance surface',
#  'beyond measure disturbed intelligence',
#  'patient Mr Edward Stapleton died apparently typhus fever accompanied anomalous symptoms excited curiosity medical attendants',
#  'Waterfront scum far common special mention though vague talk one inland trip mongrels made faint drumming red flame noted distant hills',
#  'Fredericks lip arose fiendish expression became aware direction glance without consciousness assumed',
#  'fact one hobbies',
#  'mountain upon whose top sit Helseggen Cloudy',
#  'Matters little moment rarely consigned parchment since mere ordinary purposes drawing writing nearly well adapted paper',
#  'knew strange things happened faint suggestion behind surface everything monstrous past might least darkest narrowest intricately crooked alleys utterly perished',
#  'Nobody enemies ever calls Suky Snobbs',
#  'arrival dear cousin said fills hope',
#  'circumstance lead Perdita suspect suspecting resolved',
#  'pain little pleasure much moral pain pleasure none',
#  'felt known past remote beyond recollection beyond even tenancy body possess',
#  'Three coffin heights reckoned would permit reach transom could better four',
#  'time Dombrowski Choynski Desrochers Mazurewicz top floor lodger crowding doorway landlord sent wife back telephone Dr Malkowski',
#  'wind prince air raged kingdom lashing sea fury subduing rebel earth sort obedience',
#  'season assizes approached',
#  'None non natives ever stayed late night widespread impression wise',
#  'possible suggested although letter may possession minister unquestionably may concealed elsewhere upon premises',
#  'awaked find standing bloody handed snow cabin mangled corpse neighbour Peter Slader feet',
#  'jumble French changed cry English hoarse voice shouted excitedly breath breath awakening became complete subsidence facial expression normal state uncle seized hand began relate dream whose nucleus significance could surmise kind awe',
#  'queer part Pickman got none power use selectiveness bizarrerie',
#  'language stranger suppose countryman French educated French family understand language',
#  'rapidly drew near length number forms within could discerned dark sides grew big splash oars became audible could distinguish languid form friend half raised approach',
#  'certainly nervous waiting blasphemous book hands made doubly',
#  'Perdita still great degree uneducated',
#  'silent first comer burned books',
#  'dream continued resuming tone desultory conversation held rich light censer one magnificent vases dream business life',
#  'owned curious group half castes whose frequent meetings night trips woods attracted little curiosity set sail great haste storm earth tremors March st',
#  'wonder prize',
#  'time never let go ring bolt',
#  'feared wander sight fellow creatures lest alone come claim companion',
#  'said sole effect somewhat childish experiment looking within tarn deepen first singular impression',
#  'Olney recall many wonders told even says strange kindly filled magic unfathomed voids time space',
#  'miscalculated',
#  'health impaired beyond hope cure became earnest wish died preserve daughter poverty would portion orphan state',
#  'end written full account information contemptuous amusement fellow men',
#  'Young men diffident know Clerval young wears short time',
#  'reasoned example thus drew scarabÃ¦us skull apparent upon parchment',
#  'never quitted Windsor emotions would intense Greece prey fear deplorable change Greece period anxiety sorrow seen depart two whose names symbol greatness virtue',
#  'Although two time pieces chamber struck individual seconds accurately together yet difficulty holding steadily mind tones respective momentary errors',
#  'Thats capital similes',
#  'Oh ten thousandth portion anguish mine lingering detail execution',
#  'beneath brown pall leaves rotted festered antediluvian forest darkness could trace sinister outlines low mounds characterised lightning pierced region',
#  'dream said daemon',
#  'permitted occasionally stooping patting proceeded',
#  'lived temple glorified intensest sense devotion rapture walked consecrated contemplating power excellence stood beside like youth Transformed real dream Cloathing palpable familiar golden exhalations dawn',
#  'Many went high Belfast ensure shorter passage journeying south Scotland joined poorer natives country poured one consent England',
#  'Induction posteriori would brought phrenology admit innate primitive principle human action paradoxical something may call perverseness want characteristic term',
#  'made men dream knew enough keep away',
#  'truth much owners cats hated odd folk feared instead berating brutal assassins merely took care cherished pet mouser stray toward remote hovel dark trees',
#  'lady question portion proved mouth',
#  'thou didst seek extinction might cause greater wretchedness yet mode unknown thou hadst ceased think feel thou wouldst desire vengeance greater feel',
#  'bold diddle',
#  'sentiments profound respect obedient servant VON JUNG',
#  'obtuse instrument clearly stone pavement yard upon victim fallen window looked upon bed',
#  'architecture embellishments chamber evident design dazzle astound',
#  'Among highly distinguished Prince Zaimi ambassador England free States Greece daughter young Princess Evadne passed much time Windsor Castle',
#  'Another circumstance strengthened confirmed feelings',
#  'Secondly settled Gods man continue species discovered organ amativeness forthwith',
#  'first spoken nearest whole assembly gathered found listened',
#  'polished desert quarried marble walls height cubits breadth chariots might pass men drave along top',
#  'fortune make Thingum resumed Mr Crab governor millstone neck',
#  'servants means numerous',
#  'Shame seemed hold back yet evidently wished establish renewal confidence affection',
#  'obtained father respite weeks',
#  'imminent peril could remain passive chief attention occupied unfortunate guest whose illness increased degree entirely confined bed',
#  'object larger good sized rat quaintly called townspeople Brown Jenkin seemed fruit remarkable case sympathetic herd delusion less eleven persons testified glimpsing',
#  'may cease argue point consent',
#  'perfectly self possessed accosted us courtesy seemed immediately enter feelings make one us',
#  'took arm proceeded',
#  'slowly became merged sense retirement consciousness solitude',
#  'box go extra state room',
#  'thousand injuries Fortunato borne best could ventured upon insult vowed revenge',
#  'second sight efficient properly managed',
#  'moment soul elevated debasing miserable fears contemplate divine ideas liberty self sacrifice sights monuments remembrancers',
#  'began experience intervals severe pain head especially ears still however breathing tolerable freedom',
#  'silent sleepy staring houses backwoods tell lain hidden since early days communicative loath shake drowsiness helps forget',
#  'case commenced collation analysis shorter words word single letter occurred likely example considered solution assured',
#  'Six years passed since resolved present undertaking',
#  'short time sight doubt reached home safety',
#  'boldness language gave weight knew spoke truth truth known acknowledged',
#  'Bates Street drew yawning vestibule two shambling figures crossed front soon way approaching open space Eliot Street obliquely crosses Washington intersection South',
#  'assembled towards evening Perdita insisted recourse music',
#  'suddenly stars blotted sky even bright Deneb Vega ahead lone Altair Fomalhaut behind us',
#  'suppose called Ourang Outang',
#  'well know whole earth sacrifise would make labour would undergo mere hope might bring ease',
#  'formed single broad thick plank tulip wood',
#  'bank slopes upward stream gentle ascent forming broad sward grass texture resembling nothing much velvet brilliancy green would bear comparison tint purest emerald',
#  'heart one like secret thoughts working secret tortures ought seek discover',
#  'Supporting still lagged distance half mile many stoppages shivering fits half faintings slipt supporting arm snow torrent tears averred must taken could proceed',
#  'radical theory reanimation saw nothing immature vagaries youthful enthusiast whose slight form yellow hair spectacled blue eyes soft voice gave hint supernormal almost diabolical power cold brain within',
#  'measures two points grace inimitable offers Majesty choice',
#  'especial slightest appearance mystery point exactly comprehend puts pitiable state agitation',
#  'Like many excellent people seemed possessed spirit tantalization might easily casual glance mistaken malevolence',
#  'Upon eighth night usually cautious opening door',
#  'Mrs Frye proposed telephoning neighbours Elmer agree noise splintering wood burst upon deliberations',
#  'faint even fainter hateful modernity accursed city made',
#  'farther intentions ascertained safely promise readers additional information either Monday course next day farthest',
#  'respects even unworthy serious refutation',
#  'Yet could find',
#  'Dr Barnard watching patient thought noticed pale blue eyes certain gleam peculiar quality flaccid lips imperceptible tightening intelligent determination',
#  'Leaning upon arm gallant Pompey attended respectable distance Diana proceeded one populous pleasant streets deserted Edina',
#  'writer spoke acute bodily illness mental disorder oppressed earnest desire see best indeed personal friend view attempting cheerfulness society alleviation malady',
#  'Immediately upon detecting motion arm begins move let withdraw piece perceiving error manoeuvre',
#  'kept track deaths circumstances systematic care',
#  'much toil found',
#  'length removing carefully meerschaum right left corner mouth condescended speak',
#  'hoax sort people believe general term matters comprehension',
#  'alone knew weight Raymond attached success',
#  'town city one one cabins gave place houses simple beautiful houses brick wood stone steps iron railings fanlights doors',
#  ...]

# %% [markdown]
# ## TF-IDF: calcul de fréquence
#
# Le calcul [tf-idf](https://fr.wikipedia.org/wiki/TF-IDF) (term *frequency–inverse document frequency*)
# permet de calculer un score de proximité entre un terme de recherche et un
# document (c’est ce que font les moteurs de recherche).
#
# -   La partie `tf` calcule une fonction croissante de la fréquence du terme de recherche dans le document à l’étude ;
# -   La partie `idf` calcule une fonction inversement proportionnelle à la fréquence du terme dans l’ensemble des documents (ou corpus).
#
# Le score total, obtenu en multipliant les deux composantes,
# permet ainsi de donner un score d’autant plus élevé que le terme est surréprésenté dans un document
# (par rapport à l’ensemble des documents).
# Il existe plusieurs fonctions, qui pénalisent plus ou moins les documents longs,
# ou qui sont plus ou moins *smooth*.

# %% [markdown]
# <div class="alert alert-success" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #3fb618;">
# <h3 class="alert-heading"><i class="fa fa-pencil"></i> Exercice 6 : TF-IDF: calcul de fréquence</h3>
#
# 1.  Utiliser le vectoriseur TF-IdF de `scikit-learn` pour transformer notre corpus en une matrice `document x terms`. Au passage, utiliser l’option `stop_words` pour ne pas provoquer une inflation de la taille de la matrice. Nommer le modèle `tfidf` et le jeu entraîné `tfs`.
# 2.  Après avoir construit la matrice de documents x terms avec le code suivant, rechercher les lignes où les termes ayant la structure `abandon` sont non-nuls.
# 3.  Trouver les 50 extraits où le score TF-IDF est le plus élevé et l’auteur associé. Vous devriez obtenir le classement suivant :
#
# </div>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 14
#      12 for author in train['Author'].unique():
#      13     author_indices = train[train['Author'] == author].index
# ---> 14     author_scores = tfs[author_indices, :][:, abandon_indices].max(axis=1).toarray().flatten()
#      15     top_indices = author_indices[author_scores.argsort()[::-1][:50]]
#      16     top_excerpts.extend(df.loc[top_indices])
#
# File c:\ProgramData\anaconda3\Lib\site-packages\scipy\sparse\_index.py:44, in IndexMixin.__getitem__(self, key)
#      43 def __getitem__(self, key):
# ---> 44     row, col = self._validate_indices(key)
#      46     # Dispatch to specialized methods.
#      47     if isinstance(row, INT_TYPES):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\scipy\sparse\_index.py:156, in IndexMixin._validate_indices(self, key)
#     154         row += M
#     155 elif not isinstance(row, slice):
# --> 156     row = self._asindices(row, M)
#     158 if isintlike(col):
#     159     col = int(col)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\scipy\sparse\_index.py:187, in IndexMixin._asindices(self, idx, length)
#     185 # Check bounds
#     186 max_indx = x.max()
# --> 187 if max_indx >= length:
#     188     raise IndexError('index (%d) out of range' % max_indx)
#     190 min_indx = x.min()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %% [markdown]
# Les lignes où les termes de abandon sont non nuls
# sont les suivantes :

# %%
# Out:
# Index([    4,   116,   215,   571,   839,  1042,  1052,  1069,  2247,  2317,
#         2505,  3023,  3058,  3245,  3380,  3764,  3886,  4425,  5289,  5576,
#         5694,  6812,  7500,  9013,  9021,  9077,  9560, 11229, 11395, 11451,
#        11588, 11827, 11989, 11998, 12122, 12158, 12189, 13666, 15259, 16516,
#        16524, 16759, 17547, 18019, 18072, 18126, 18204, 18251],
#       dtype='int64')
# <p>5 rows × 24937 columns</p>
# </div>

# %%
# Out:
# Author
# MWS    22
# HPL    15
# EAP    13
# Name: Text, dtype: int64

# %% [markdown]
# Les 10 scores les plus élevés sont les suivants :

# %%
# Out:
# ['We could not fear we did not.' '"And now I do not fear death.'
#  'Be of heart and fear nothing.' 'I smiled, for what had I to fear?'
#  'Indeed I had no fear on her account.'
#  'I have not the slightest fear for the result.'
#  'At length, in an abrupt manner she asked, "Where is he?" "O, fear not," she continued, "fear not that I should entertain hope Yet tell me, have you found him?'
#  '"I fear you are right there," said the Prefect.'
#  'I went down to open it with a light heart, for what had I now to fear?']

# %% [markdown]
# On remarque que les scores les plus élevés sont soient des extraits courts où le mot apparait une seule fois, soit des extraits plus longs où le mot fear apparaît plusieurs fois.

# %% [markdown]
# <div class="alert alert-info" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #007bff80;">
# <h3 class="alert-heading"><i class="fa fa-comment"></i> Note</h3>
#
# La matrice `document x terms` est un exemple typique de matrice *sparse* puisque, dans des corpus volumineux, une grande diversité de vocabulaire peut être trouvée.
#
# </div>

# %% [markdown]
# ## Approche contextuelle : les *n-grams*
#
# Jusqu’à présent, dans l’approche *bag of words*, l’ordre des mots n’avait pas d’importance.
# On considère qu’un texte est une collection de
# mots tirés indépendamment, de manière plus ou moins fréquente en fonction de leur probabilité
# d’occurrence. Cependant, tirer un mot particulier n’affecte pas les chances de tirer certains mots
# ensuite, de manière conditionnelle.
#
# Une manière d’introduire des liens entre les séries de *tokens* sont les *n-grams*.
# On s’intéresse non seulement aux mots et à leur fréquence, mais aussi aux mots qui suivent. Cette approche est essentielle pour désambiguiser les homonymes. Le calcul de *n-grams* [1] constitue la méthode la plus simple pour tenir compte du contexte.
#
# Pour être en mesure de mener cette analyse, il est nécessaire de télécharger un corpus supplémentaire :
#
# [1] On parle de *bigrams* pour les co-occurences de mots deux-à-deux, *trigrams* pour les co-occurences trois-à-trois, etc.

# %%
import nltk

nltk.download("genesis")
nltk.corpus.genesis.words("english-web.txt")
# Out:
# [nltk_data] Downloading package genesis to /github/home/nltk_data...
# [nltk_data]   Package genesis is already up-to-date!
# ['In', 'the', 'beginning', 'God', 'created', 'the', ...]

# %% [markdown]
# `NLTK` offre des methodes pour tenir compte du contexte. Pour ce faire, nous calculons les n-grams, c’est-à-dire l’ensemble des co-occurrences successives de mots n-à-n. En général, on se contente de bi-grams, au mieux de tri-grams:
#
# -   les modèles de classification, analyse du sentiment, comparaison de documents, etc. qui comparent des n-grams avec n trop grands sont rapidement confrontés au problème de données sparse, cela réduit la capacité prédictive des modèles ;
# -   les performances décroissent très rapidement en fonction de n, et les coûts de stockage des données augmentent rapidement (environ n fois plus élevé que la base de données initiale).
#
# On va, rapidement, regarder dans quel contexte apparaît le mot `fear` dans
# l’oeuvre d’Edgar Allan Poe (EAP). Pour cela, on transforme d’abord
# le corpus EAP en tokens `NLTK` :

# %%
eap_clean = train[train["Author"] == "EAP"]
eap_clean = " ".join(eap_clean["Text"])
tokens = eap_clean.split()
print(tokens[:10])
text = nltk.Text(tokens)
print(text)
# Out:
# ['This', 'process,', 'however,', 'afforded', 'me', 'no', 'means', 'of', 'ascertaining', 'the']
# <Text: This process, however, afforded me no means of...>

# %% [markdown]
# Vous aurez besoin des fonctions `BigramCollocationFinder.from_words` et `BigramAssocMeasures.likelihood_ratio` :

# %% [markdown]
# <div class="alert alert-success" role="alert" style="color: rgba(0,0,0,.8); background-color: white; margin-top: 1em; margin-bottom: 1em; margin:1.5625emauto; padding:0 .6rem .8rem!important;overflow:hidden; page-break-inside:avoid; border-radius:.25rem; box-shadow:0 .2rem .5rem rgba(0,0,0,.05),0 0 .05rem rgba(0,0,0,.1); transition:color .25s,background-color .25s,border-color .25s ; border-right: 1px solid #dee2e6 ; border-top: 1px solid #dee2e6 ; border-bottom: 1px solid #dee2e6 ; border-left:.2rem solid #3fb618;">
# <h3 class="alert-heading"><i class="fa fa-pencil"></i> Exercice 7  : n-grams et contexte du mot fear</h3>
#
# 1.  Utiliser la méthode `concordance` pour afficher le contexte dans lequel apparaît le terme `fear`.
# 2.  Sélectionner et afficher les meilleures collocations, par exemple selon le critère du ratio de vraisemblance.
#
# Lorsque deux mots sont fortement associés, cela est parfois dû au fait qu’ils apparaissent rarement. Il est donc parfois nécessaire d’appliquer des filtres, par exemple ignorer les bigrammes qui apparaissent moins de 5 fois dans le corpus.
#
# 1.  Refaire la question précédente en utilisant toujours un modèle `BigramCollocationFinder` suivi de la méthode `apply_freq_filter` pour ne conserver que les bigrammes présents au moins 5 fois. Puis, au lieu d’utiliser la méthode de maximum de vraisemblance, testez la méthode `nltk.collocations.BigramAssocMeasures().jaccard`.
#
# 2.  Ne s’intéresser qu’aux *collocations* qui concernent le mot *fear*
#
# </div>

# %% [markdown]
# Avec la méthode `concordance` (question 1),
# la liste devrait ressembler à celle-ci :

# %%
tokens = train['Text'].apply(word_tokenize)

# Create NLTK Text objects for each tokenized text
text_objects = [Text(token_list) for token_list in tokens]

# Use the concordance method to display the context of the word "fear" for each text
for text_obj in text_objects:
    text_obj.concordance("fear")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tokens = train['Text'].apply(word_tokenize)
#       3 # Create NLTK Text objects for each tokenized text
#       4 text_objects = [Text(token_list) for token_list in tokens]
#
# NameError: name 'train' is not defined

# %% [markdown]
# Même si on peut facilement voir le mot avant et après, cette liste est assez difficile à interpréter car elle recoupe beaucoup d’informations.
#
# La `collocation` consiste à trouver les bi-grammes qui
# apparaissent le plus fréquemment ensemble. Parmi toutes les paires de deux mots observées,
# il s’agit de sélectionner, à partir d’un modèle statistique, les “meilleures”.
# On obtient donc avec cette méthode (question 2):

# %%
# Out:
# [('of', 'the'),
#  ('in', 'the'),
#  ('had', 'been'),
#  ('to', 'be'),
#  ('have', 'been'),
#  ('I', 'had'),
#  ('It', 'was'),
#  ('it', 'is'),
#  ('could', 'not'),
#  ('from', 'the'),
#  ('upon', 'the'),
#  ('more', 'than'),
#  ('it', 'was'),
#  ('would', 'have'),
#  ('with', 'a'),
#  ('did', 'not'),
#  ('I', 'am'),
#  ('the', 'a'),
#  ('at', 'once'),
#  ('might', 'have')]

# %% [markdown]
# Si on modélise les meilleures collocations:

# %%
# Out:
# "Gad Fly"
# 'Hum Drum,'
# 'Rowdy Dow,'
# Brevet Brigadier
# BarriÃ¨re du
# ugh ugh
# Ourang Outang
# Chess Player
# John A.
# A. B.
# hu hu
# General John
# 'Oppodeldoc,' whoever
# mille, mille,
# Brigadier General

# %% [markdown]
# Cette liste a un peu plus de sens,
# on a des noms de personnages, de lieux mais aussi des termes fréquemment employés ensemble
# (*Chess Player* par exemple).
#
# En ce qui concerne les *collocations* du mot fear :

# %%
# Out:
# [('fear', 'of'), ('fear', 'God'), ('I', 'fear'), ('the', 'fear'), ('The', 'fear'), ('fear', 'him'), ('you', 'fear')]

# %% [markdown]
# Si on mène la même analyse pour le terme *love*, on remarque que de manière logique, on retrouve bien des sujets généralement accolés au verbe :

# %%
# Out:
# [('love', 'me'), ('love', 'he'), ('will', 'love'), ('I', 'love'), ('love', ','), ('you', 'love'), ('the', 'love')]

# %% [markdown]
# ## Références
#
# Galiana, Lino, and Milena Suarez Castillo. 2022. “Fuzzy Matching on Big-Data an Illustration with Scanner Data and Crowd-Sourced Nutritional Data.”
#
# Galiana, Lino, François Sémécurbe, Benjamin Sakarovitch, and Zbigniew Smoreda. 2020. “Residential Segregation, Daytime Segregation and Spatial Frictions: An Analysis from Mobile Phone Data.”
