# %%
import numpy as np
import imageio.v2 as misc
import matplotlib.pyplot as plt
damier = misc.imread("damier-ng.jpeg")
paysage = misc.imread("paysage_zen.png")
misc.imsave("damier-ng.png", damier)

# %%
paysage.shape
# Out:
# (432, 1426, 3)

# %%
plt.imshow(paysage)

# %%
damier.shape
# Out:
# (198, 255, 3)

# %%
plt.imshow(damier,cmap='gray')

# %%
def bord(image, k):
    im_temp = image.copy()
    im_temp[:,:k] = 0
    im_temp[:,-k:] = 0
    im_temp[:k,:] = 0
    im_temp[-k:,:] = 0           
    return(im_temp)
    
    return image_avec_bord

plt.imshow(bord(damier,5),cmap="gray")

# %%
def inverse(image):
    image_inversee = 255 - image
    return image_inversee
plt.imshow(inverse(damier),cmap="gray")

# %%
def masque_blanc(image,pos, lon, lar):
    im_temp = image.copy()
    im_temp[pos[0]:pos[0]+lon,pos[1]:pos[1]+lar] = 255
    return(im_temp)

plt.imshow(masque_blanc(damier,[100,50], 100, 100, ),cmap="gray")

# %%
def inverse_horiz(image):
    return image[:, ::-1]

plt.imshow(inverse_horiz(damier),cmap="gray")

# %%
def inverse_vert(image):

    return image[::-1, :]
plt.imshow(inverse_vert(damier),cmap="gray")
